# %% [markdown]
# # Readme
# Code to
# * remove nulls
# * normalize
# * Manually calc eucl. distance using scikit-learn

# %%
import pandas as pd
from scipy.spatial import distance

# %% [markdown]
# # Functions

# %%
def get_df_missing_values(df):
    missing_value_df = pd.DataFrame({
        'column_name': dc_listings.columns
        , 'percent_missing': round(((df.isnull().sum())/df.shape[0])*100, 2)
    })

    missing_value_df.sort_values(by=['percent_missing'], inplace=True)

    return missing_value_df

# %% [markdown]
# # Get the data

# %%
dc_listings = pd.read_csv('../data/dc_airbnb.csv')
stripped_commas = dc_listings['price'].str.replace(',', '')
stripped_dollars = stripped_commas.str.replace('$', '')
dc_listings['price'] = stripped_dollars.astype('float')

# %% [markdown]
# # Remove unnecessary/unuseful columns
#
# We do not need
#
# * non-numeric
# * non-ordinal
# * null

# %%
dc_listings.head()
# Out:
#   host_response_rate host_acceptance_rate  host_listings_count  accommodates  \
# 0                92%                  91%                   26             4
# 1                90%                 100%                    1             6
# 2                90%                 100%                    2             1
# 3               100%                  NaN                    1             2
# 4                92%                  67%                    1             4
#
#          room_type  bedrooms  bathrooms  beds  price cleaning_fee  \
# 0  Entire home/apt       1.0        1.0   2.0  160.0      $115.00
# 1  Entire home/apt       3.0        3.0   3.0  350.0      $100.00
# 2     Private room       1.0        2.0   1.0   50.0          NaN
# 3     Private room       1.0        1.0   1.0   95.0          NaN
# 4  Entire home/apt       1.0        1.0   1.0   50.0       $15.00
#
#   security_deposit  minimum_nights  maximum_nights  number_of_reviews  \
# 0          $100.00               1            1125                  0
# 1              NaN               2              30                 65
# 2              NaN               2            1125                  1
# 3              NaN               1            1125                  0
# 4          $450.00               7            1125                  0
#
#     latitude  longitude           city zipcode state
# 0  38.890046 -77.002808     Washington   20003    DC
# 1  38.880413 -76.990485     Washington   20003    DC
# 2  38.955291 -76.986006    Hyattsville   20782    MD
# 3  38.872134 -77.019639     Washington   20024    DC
# 4  38.996382 -77.041541  Silver Spring   20910    MD

# %%
dc_listings.drop(columns=[
    'room_type'
    , 'host_response_rate'
    , 'host_acceptance_rate'
    , 'host_listings_count'
    , 'latitude'
    , 'longitude'
    , 'city'
    , 'zipcode'
    , 'state'
    
], inplace=True)

dc_listings.head()
# Out:
#    accommodates  bedrooms  bathrooms  beds  price cleaning_fee  \
# 0             4       1.0        1.0   2.0  160.0      $115.00
# 1             6       3.0        3.0   3.0  350.0      $100.00
# 2             1       1.0        2.0   1.0   50.0          NaN
# 3             2       1.0        1.0   1.0   95.0          NaN
# 4             4       1.0        1.0   1.0   50.0       $15.00
#
#   security_deposit  minimum_nights  maximum_nights  number_of_reviews
# 0          $100.00               1            1125                  0
# 1              NaN               2              30                 65
# 2              NaN               2            1125                  1
# 3              NaN               1            1125                  0
# 4          $450.00               7            1125                  0

# %% [markdown]
# ## Remove nulls
# * beds, bedrooms and bathrooms have  < 1 % missing rows --> remove rows
# * cleaning_fee + security_deposit have too many missing rows be be deleted --> drop columns

# %%
missing_values = get_df_missing_values(dc_listings)

missing_values
# Out:
#                          column_name  percent_missing
# accommodates            accommodates             0.00
# price                          price             0.00
# minimum_nights        minimum_nights             0.00
# maximum_nights        maximum_nights             0.00
# number_of_reviews  number_of_reviews             0.00
# beds                            beds             0.30
# bedrooms                    bedrooms             0.56
# bathrooms                  bathrooms             0.73

# %%
# drop columns
dc_listings.drop(columns = ['cleaning_fee', 'security_deposit'], inplace=True, errors='ignore')

dc_listings.dropna(subset = ['beds', 'bedrooms', 'bathrooms'], inplace=True, axis=0)

missing_values = get_df_missing_values(dc_listings)

missing_values
# Out:
#                          column_name  percent_missing
# accommodates            accommodates              0.0
# bedrooms                    bedrooms              0.0
# bathrooms                  bathrooms              0.0
# beds                            beds              0.0
# price                          price              0.0
# minimum_nights        minimum_nights              0.0
# maximum_nights        maximum_nights              0.0
# number_of_reviews  number_of_reviews              0.0

# %% [markdown]
# # Normalize

# %%
dc_listings.describe()
# Out:
#        host_listings_count  accommodates     bedrooms    bathrooms  \
# count          3723.000000   3723.000000  3702.000000  3696.000000
# mean             13.517325      3.195004     1.210157     1.256358
# std              64.534408      2.012216     0.839851     0.585539
# min               1.000000      1.000000     0.000000     0.000000
# 25%               1.000000      2.000000     1.000000     1.000000
# 50%               1.000000      2.000000     1.000000     1.000000
# 75%               3.000000      4.000000     1.000000     1.000000
# max             480.000000     16.000000    10.000000     8.000000
#
#               beds        price  minimum_nights  maximum_nights  \
# count  3712.000000  3723.000000     3723.000000    3.723000e+03
# mean      1.643319   149.165995        2.250067    5.803069e+05
# std       1.182117   140.110699        3.622879    3.519552e+07
# min       1.000000    10.000000        1.000000    1.000000e+00
# 25%       1.000000    85.000000        1.000000    1.200000e+02
# 50%       1.000000   115.000000        2.000000    1.125000e+03
# 75%       2.000000   165.000000        3.000000    1.125000e+03
# max      16.000000  2822.000000      180.000000    2.147484e+09
#
#        number_of_reviews     latitude    longitude
# count        3723.000000  3723.000000  3723.000000
# mean           15.306742    38.913967   -77.023294
# std            29.645586     0.021647     0.026951
# min             0.000000    38.825061   -77.110525
# 25%             1.000000    38.901789   -77.039859
# 50%             4.000000    38.913375   -77.026410
# 75%            16.000000    38.926509   -77.002798
# max           362.000000    38.996382   -76.913137

# %%
normalized_listings = (dc_listings - dc_listings.mean())/dc_listings.std()

normalized_listings['price'] = dc_listings['price']

normalized_listings
# Out:
#       accommodates  bedrooms  bathrooms      beds  price  minimum_nights  \
# 0         0.401366 -0.249467  -0.439151  0.297345  160.0       -0.341375
# 1         1.399275  2.129218   2.969147  1.141549  350.0       -0.065038
# 2        -1.095499 -0.249467   1.264998 -0.546858   50.0       -0.065038
# 3        -0.596544 -0.249467  -0.439151 -0.546858   95.0       -0.341375
# 4         0.401366 -0.249467  -0.439151 -0.546858   50.0        1.316644
# ...            ...       ...        ...       ...    ...             ...
# 3718      0.401366 -0.249467  -0.439151  0.297345  135.0        0.211298
# 3719     -0.596544 -0.249467   1.264998 -0.546858   79.0        0.211298
# 3720      1.399275  0.939875  -0.439151  1.141549  275.0       -0.065038
# 3721     -0.596544 -0.249467  -0.439151 -0.546858  179.0       -0.065038
# 3722     -0.097589 -1.438810  -0.439151 -0.546858  110.0       -0.065038
#
#       maximum_nights  number_of_reviews
# 0          -0.016573          -0.516709
# 1          -0.016603           1.706535
# 2          -0.016573          -0.482505
# 3          -0.016573          -0.516709
# 4          -0.016573          -0.516709
# ...              ...                ...
# 3718       -0.016603           0.133163
# 3719       -0.016594           0.714626
# 3720       60.571616          -0.106264
# 3721       -0.016604           1.125071
# 3722       -0.016573          -0.482505
#
# [3671 rows x 8 columns]

# %%
normalized_listings.describe()
# Out:
#        accommodates      bedrooms     bathrooms          beds        price  \
# count  3.671000e+03  3.671000e+03  3.671000e+03  3.671000e+03  3671.000000
# mean  -1.374245e-16  1.567801e-16  1.006489e-16  3.387224e-17   148.843639
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00   137.550045
# min   -1.095499e+00 -1.438810e+00 -2.143301e+00 -5.468581e-01    10.000000
# 25%   -5.965439e-01 -2.494671e-01 -4.391515e-01 -5.468581e-01    85.000000
# 50%   -5.965439e-01 -2.494671e-01 -4.391515e-01 -5.468581e-01   115.000000
# 75%    4.013657e-01 -2.494671e-01 -4.391515e-01  2.973454e-01   165.000000
# max    6.388823e+00  1.045462e+01  1.148989e+01  1.211619e+01  2822.000000
#
#        minimum_nights  maximum_nights  number_of_reviews
# count    3.671000e+03    3.671000e+03       3.671000e+03
# mean    -2.322668e-17    9.677782e-19      -1.161334e-17
# std      1.000000e+00    1.000000e+00       1.000000e+00
# min     -3.413745e-01   -1.660422e-02      -5.167086e-01
# 25%     -3.413745e-01   -1.660086e-02      -4.825048e-01
# 50%     -6.503806e-02   -1.657250e-02      -3.798936e-01
# 75%      2.112984e-01   -1.657250e-02       3.055137e-02
# max      4.912285e+01    6.057162e+01       1.186505e+01

# %%
dc_listings.describe().loc['min','minimum_nights'] - dc_listings.describe().loc['max','minimum_nights']
# Out:
# -179.0

# %%
normalized_listings.describe().loc['min','minimum_nights'] - normalized_listings.describe().loc['max','minimum_nights']
# Out:
# -49.46422861750143

# %% [markdown]
# # Calc similarity

# %%
normalized_listings.head()
# Out:
#    accommodates  bedrooms  bathrooms      beds  price  minimum_nights  \
# 0      0.401366 -0.249467  -0.439151  0.297345  160.0       -0.341375
# 1      1.399275  2.129218   2.969147  1.141549  350.0       -0.065038
# 2     -1.095499 -0.249467   1.264998 -0.546858   50.0       -0.065038
# 3     -0.596544 -0.249467  -0.439151 -0.546858   95.0       -0.341375
# 4      0.401366 -0.249467  -0.439151 -0.546858   50.0        1.316644
#
#    maximum_nights  number_of_reviews
# 0       -0.016573          -0.516709
# 1       -0.016603           1.706535
# 2       -0.016573          -0.482505
# 3       -0.016573          -0.516709
# 4       -0.016573          -0.516709

# %%
features = ['accommodates', 'bathrooms']
first_fifth_distance = distance.euclidean(normalized_listings.loc[0, features], normalized_listings.loc[4, features])
print(first_fifth_distance)
# Out:
# 0.0

# %% [markdown]
# # Save the normalized data

# %%
normalized_listings.to_csv('../data/normalized_listings.csv')
